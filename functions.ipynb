# %%
#functions of numpy library
import numpy as np

# %%
np.random.random()
# Out:
# 0.14473019186670877

# %%
np.random.seed(1) #give same random value again and again
np.random.random()
# Out:
# 0.417022004702574

# %%
np.random.uniform(3,10) #give random value btw range(3,10)
# Out:
# 3.000800623721414

# %%
np.random.uniform(1,100,10) #give 10 random value btw 1,100
# Out:
# array([87.9336262 ,  3.71137173, 67.37628351, 42.31317543, 56.31029302,
#        14.89830692, 20.61204742, 80.2737123 , 96.857896  , 32.02899364])

# %%
np.random.uniform(1,100,10).reshape(2,5)
# Out:
# array([[69.53993895, 87.76252608, 89.56605969,  9.41937693,  4.86642354],
#        [17.81321154, 87.93610784, 10.73633655, 42.68965488, 95.83106348]])

# %%
np.random.randint(1,9) #give random integer value btw range
# Out:
# 2

# %%
np.random.randint(1,10,5)
# Out:
# array([4, 5, 9, 2, 5], dtype=int32)

# %%
np.random.randint(1,20,10).reshape(5,2)
# Out:
# array([[17, 14],
#        [10, 19],
#        [16,  1],
#        [ 5, 16],
#        [ 3,  8]], dtype=int32)

# %%
a=np.random.randint(1,10,6)

# %%
a
# Out:
# array([9, 7, 4, 8, 8, 5], dtype=int32)

# %%
np.max(a)
# Out:
# np.int32(9)

# %%
np.min(a)
# Out:
# np.int32(4)

# %%
np.argmax(a) #index of max value
# Out:
# np.int64(0)

# %%
np.argmin(a) #index of min value
# Out:
# np.int64(2)

# %%
a
# Out:
# array([9, 7, 4, 8, 8, 5], dtype=int32)

# %%
#replace odd value with -1
a[a%2!=0]=-1
a
# Out:
# array([-1, -1,  4,  8,  8, -1], dtype=int32)

# %%
#where(condition,true,false)
# Out:
# array([-1, -1,  4,  8,  8, -1], dtype=int32)

# %%
a=np.random.randint(1,50,6)
a
# Out:
# array([35, 11, 24, 16, 48, 24], dtype=int32)

# %%
np.where(a%2==1,-1,a)
# Out:
# array([-1, -1, 24, 16, 48, 24], dtype=int32)

# %%
a=np.random.randint(1,60,10)
a
# Out:
# array([26,  8, 52, 29, 11, 47, 33, 25, 24, 56], dtype=int32)

# %%
np.sort(a)
# Out:
# array([ 8, 11, 24, 25, 26, 29, 33, 47, 52, 56], dtype=int32)

# %%
#percentile

# %%
np.percentile(a,25)
# Out:
# np.float64(24.25)
