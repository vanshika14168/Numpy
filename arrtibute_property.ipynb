# %%
import numpy as np

# %%
arr1=np.array([1.,2.,3.,4.,5.,6.]) #shape
arr1.shape
# Out:
# (6,)

# %%
arr2=np.array([[1,2,3],[4,5,6],[2,6,8]])
arr2.shape
# Out:
# (3, 3)

# %%
arr3=np.array([[[1,2],[3,4]],[[1,2],[3,4]]])
arr3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[1, 2],
#         [3, 4]]])

# %%
arr3.shape
# Out:
# (2, 2, 2)

# %%
arr3.ndim #it shows demension of array
# Out:
# 3

# %%
arr2.ndim
# Out:
# 2

# %%
arr3.size  #size
# Out:
# 8

# %%
arr2.size
# Out:
# 9

# %%
arr3.itemsize #itemsize
# Out:
# 8

# %%
arr2.itemsize
# Out:
# 8

# %%
arr1.itemsize
# Out:
# 8

# %%
arr2.dtype    #dtype
# Out:
# dtype('int64')

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr2.astype('float')     #astype
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.],
#        [2., 6., 8.]])

# %%
arr1.astype('float')
# Out:
# array([1., 2., 3., 4., 5., 6.])
