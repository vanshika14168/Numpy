# %%
import numpy as np

# %%
lista=range(100)
arr1=np.arange(100)

# %%
#check memory
import sys

# %%
print(sys.getsizeof(45)*len(lista))
# Out:
# 2800

# %%
print(arr1.itemsize*arr1.size)
# Out:
# 800

# %%
#numpy array faster then list
import time

# %%
x=range(10000000)
y=range(10000000,20000000)
start_time=time.time()

c=[(x+y) for x,y in zip(x,y)] #function for adding two numbers and store in list
print(time.time()-start_time)
# Out:
# 1.1258149147033691

# %%
a=np.arange(10000000)
b=np.arange(10000000,20000000)
start_time=time.time()
c=a+b
print(time.time()-start_time)
# Out:
# 0.15828490257263184
